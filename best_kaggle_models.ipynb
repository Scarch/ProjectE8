# %% [markdown]
# # Importing libraries

# %% [markdown]
# Importing libraries for managing the data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing library that allows us to use Extreme Gradiant Boosting Regression algorithm

# %%
from xgboost import XGBRegressor

# %% [markdown]
# Importing library that allows us to use a Random Forest Regression model

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# Libraries for using tensorflow (neural network algorithm)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import BatchNormalization

# %% [markdown]
# Prediction evaluation libraries

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Library that allows us to scale the features of our data (important for neural networks)

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loading data

# %% [markdown]
# File "*kaggleData/train.csv*" contains hourly data from 2011 to 2012 (both inclusive) for training the machine learning models. It lists how many bike rides were done on a certain hour and also the weather conditions. Some of the data has been removed and added to the "*kaggleData/test.csv*" file, where the hourly bike rental counts have been removed. The predictions must be done on this data and then sent to the Kaggle competition.

# %%
kaggle_training_data = pd.read_csv("kaggleData/train.csv")
X_test = pd.read_csv("kaggleData/test.csv")

# %%
kaggle_training_data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %%
X_test
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-20 00:00:00       1        0           1        1  10.66
# 1     2011-01-20 01:00:00       1        0           1        1  10.66
# 2     2011-01-20 02:00:00       1        0           1        1  10.66
# 3     2011-01-20 03:00:00       1        0           1        1  10.66
# 4     2011-01-20 04:00:00       1        0           1        1  10.66
# ...                   ...     ...      ...         ...      ...    ...
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed
# 0     11.365        56    26.0027
# 1     13.635        56     0.0000
# 2     13.635        56     0.0000
# 3     12.880        56    11.0014
# 4     12.880        56    11.0014
# ...      ...       ...        ...
# 6488  12.880        60    11.0014
# 6489  12.880        60    11.0014
# 6490  12.880        60    11.0014
# 6491  13.635        56     8.9981
# 6492  13.635        65     8.9981
#
# [6493 rows x 9 columns]

# %% [markdown]
# # Creating new columns

# %% [markdown]
# Converting object type "datetime" column into datetime type. This is important because then we can divide that column into more descriptive columns

# %%
kaggle_training_data["datetime"] = pd.to_datetime(kaggle_training_data["datetime"])
X_test["datetime"] = pd.to_datetime(X_test["datetime"])

# %% [markdown]
# Splitting "datetime" column into "year", "month", "day" and "hour" columns

# %%
kaggle_training_data["year"] = kaggle_training_data["datetime"].dt.year
kaggle_training_data["month"] = kaggle_training_data["datetime"].dt.month
kaggle_training_data["day"] = kaggle_training_data["datetime"].dt.day
kaggle_training_data["hour"] = kaggle_training_data["datetime"].dt.hour

X_test["year"] = X_test["datetime"].dt.year
X_test["month"] = X_test["datetime"].dt.month
X_test["day"] = X_test["datetime"].dt.day
X_test["hour"] = X_test["datetime"].dt.hour

# %% [markdown]
# Creating a "dayofweek" column to improve the performance of the machine learning models

# %%
kaggle_training_data["dayofweek"] = kaggle_training_data["datetime"].dt.dayofweek
X_test["dayofweek"] = X_test["datetime"].dt.dayofweek

# %% [markdown]
# # Modifying "year" column

# %% [markdown]
# The model's performance is unaffected by whether the years start from 2011 or 0. For simplicity, we adjusted the dataset so that the year starts from 0 by subtracting 2013.

# %%
kaggle_training_data["year"] = kaggle_training_data["year"] - 2011
X_test["year"] = X_test["year"] - 2011

# %% [markdown]
# # Removing unnecessary columns

# %% [markdown]
# Removing "casual" and "registered" columns from the training set, since they aren't used as features and also not as target values

# %%
kaggle_training_data.drop(["casual", "registered"], inplace=True, axis=1)

# %% [markdown]
# Saving the "datetime" column of the test set to later on use it in submission file

# %%
submission_datetime = X_test["datetime"]

# %% [markdown]
# Removing "datetime" column, since machine learning models usually can't read it. We already converted and divided it into appropriate columns.

# %%
kaggle_training_data.drop("datetime", inplace=True, axis=1)
X_test.drop("datetime", inplace=True, axis=1)

# %% [markdown]
# Removing "month" column, since this way the model produces better results

# %%
kaggle_training_data_xgb = kaggle_training_data.drop("month", axis=1)
X_test_xgb = X_test.drop("month", axis=1)

# %%
kaggle_training_data_xgb
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 0           1        0           0        1   9.84  14.395        81
# 1           1        0           0        1   9.02  13.635        80
# 2           1        0           0        1   9.02  13.635        80
# 3           1        0           0        1   9.84  14.395        75
# 4           1        0           0        1   9.84  14.395        75
# ...       ...      ...         ...      ...    ...     ...       ...
# 10881       4        0           1        1  15.58  19.695        50
# 10882       4        0           1        1  14.76  17.425        57
# 10883       4        0           1        1  13.94  15.910        61
# 10884       4        0           1        1  13.94  17.425        61
# 10885       4        0           1        1  13.12  16.665        66
#
#        windspeed  count  year  day  hour  dayofweek
# 0         0.0000     16     0    1     0          5
# 1         0.0000     40     0    1     1          5
# 2         0.0000     32     0    1     2          5
# 3         0.0000     13     0    1     3          5
# 4         0.0000      1     0    1     4          5
# ...          ...    ...   ...  ...   ...        ...
# 10881    26.0027    336     1   19    19          2
# 10882    15.0013    241     1   19    20          2
# 10883    15.0013    168     1   19    21          2
# 10884     6.0032    129     1   19    22          2
# 10885     8.9981     88     1   19    23          2
#
# [10886 rows x 13 columns]

# %%
X_test_xgb
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0          1        0           1        1  10.66  11.365        56
# 1          1        0           1        1  10.66  13.635        56
# 2          1        0           1        1  10.66  13.635        56
# 3          1        0           1        1  10.66  12.880        56
# 4          1        0           1        1  10.66  12.880        56
# ...      ...      ...         ...      ...    ...     ...       ...
# 6488       1        0           1        2  10.66  12.880        60
# 6489       1        0           1        2  10.66  12.880        60
# 6490       1        0           1        1  10.66  12.880        60
# 6491       1        0           1        1  10.66  13.635        56
# 6492       1        0           1        1  10.66  13.635        65
#
#       windspeed  year  day  hour  dayofweek
# 0       26.0027     0   20     0          3
# 1        0.0000     0   20     1          3
# 2        0.0000     0   20     2          3
# 3       11.0014     0   20     3          3
# 4       11.0014     0   20     4          3
# ...         ...   ...  ...   ...        ...
# 6488    11.0014     1   31    19          0
# 6489    11.0014     1   31    20          0
# 6490    11.0014     1   31    21          0
# 6491     8.9981     1   31    22          0
# 6492     8.9981     1   31    23          0
#
# [6493 rows x 12 columns]

# %% [markdown]
# # Splitting training data into features (X) and target (y)

# %% [markdown]
# Splitting the training data so we could use it to train the model

# %%
X_train_xgb = kaggle_training_data_xgb.drop("count", axis=1)
y_train_xgb = kaggle_training_data_xgb["count"]

# %% [markdown]
# # Training an extreme gradiant boosting (XGBoost) regression model

# %% [markdown]
# Creating a model and training it. We also used gridsearch for hyperparameter tuning (in kaggle_model.ipynb), but found best results by just using default parameters.

# %%
xgb_model = XGBRegressor(objective="reg:gamma", random_state=0)
xgb_model.fit(X_train_xgb, y_train_xgb)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, objective='reg:gamma', ...)

# %% [markdown]
# # Predicting the test results and writing them into a file

# %% [markdown]
# Predicting test data

# %%
y_test_xgb = xgb_model.predict(X_test_xgb)

# %% [markdown]
# Creating a function to save the test data into a file

# %%
def results_to_file(y_test, file_name):
    prediction = pd.DataFrame({
        "datetime": submission_datetime,
        "count": y_test
    })

    prediction.to_csv("./submissions/" + file_name + ".csv", index=False)

# %% [markdown]
# Saving the results into a file

# %%
results_to_file(y_test_xgb, "submission_xgb_gamma_16")

# %% [markdown]
# Competition score (Root Mean Squared Logarithmic Error): 0.39899

# %% [markdown]
# # Preparing data for random forest regression model

# %% [markdown]
# One hot encoding categorical features

# %%
X_train_rfr = X_train_xgb.copy()
y_train_rfr = y_train_xgb.copy()

X_test_rfr = X_test_xgb.copy()

one_hot_encoded_columns = ["season", "weather", "dayofweek"]

for feature in one_hot_encoded_columns:
    one_hot_encoded_feature = pd.get_dummies(X_train_rfr[feature], prefix=feature)
    X_train_rfr = pd.concat([X_train_rfr, one_hot_encoded_feature], axis=1)
    X_train_rfr.drop(feature, inplace=True, axis=1)

for feature in one_hot_encoded_columns:
    one_hot_encoded_feature = pd.get_dummies(X_test_rfr[feature], prefix=feature)
    X_test_rfr = pd.concat([X_test_rfr, one_hot_encoded_feature], axis=1)
    X_test_rfr.drop(feature, inplace=True, axis=1)

# %%
X_train_rfr
# Out:
#        holiday  workingday   temp   atemp  humidity  windspeed  year  day  \
# 0            0           0   9.84  14.395        81     0.0000     0    1
# 1            0           0   9.02  13.635        80     0.0000     0    1
# 2            0           0   9.02  13.635        80     0.0000     0    1
# 3            0           0   9.84  14.395        75     0.0000     0    1
# 4            0           0   9.84  14.395        75     0.0000     0    1
# ...        ...         ...    ...     ...       ...        ...   ...  ...
# 10881        0           1  15.58  19.695        50    26.0027     1   19
# 10882        0           1  14.76  17.425        57    15.0013     1   19
# 10883        0           1  13.94  15.910        61    15.0013     1   19
# 10884        0           1  13.94  17.425        61     6.0032     1   19
# 10885        0           1  13.12  16.665        66     8.9981     1   19
#
#        hour  season_1  ...  weather_2  weather_3  weather_4  dayofweek_0  \
# 0         0      True  ...      False      False      False        False
# 1         1      True  ...      False      False      False        False
# 2         2      True  ...      False      False      False        False
# 3         3      True  ...      False      False      False        False
# 4         4      True  ...      False      False      False        False
# ...     ...       ...  ...        ...        ...        ...          ...
# 10881    19     False  ...      False      False      False        False
# 10882    20     False  ...      False      False      False        False
# 10883    21     False  ...      False      False      False        False
# 10884    22     False  ...      False      False      False        False
# 10885    23     False  ...      False      False      False        False
#
#        dayofweek_1  dayofweek_2  dayofweek_3  dayofweek_4  dayofweek_5  \
# 0            False        False        False        False         True
# 1            False        False        False        False         True
# 2            False        False        False        False         True
# 3            False        False        False        False         True
# 4            False        False        False        False         True
# ...            ...          ...          ...          ...          ...
# 10881        False         True        False        False        False
# 10882        False         True        False        False        False
# 10883        False         True        False        False        False
# 10884        False         True        False        False        False
# 10885        False         True        False        False        False
#
#        dayofweek_6
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 10881        False
# 10882        False
# 10883        False
# 10884        False
# 10885        False
#
# [10886 rows x 24 columns]

# %%
X_test_rfr
# Out:
#       holiday  workingday   temp   atemp  humidity  windspeed  year  day  \
# 0           0           1  10.66  11.365        56    26.0027     0   20
# 1           0           1  10.66  13.635        56     0.0000     0   20
# 2           0           1  10.66  13.635        56     0.0000     0   20
# 3           0           1  10.66  12.880        56    11.0014     0   20
# 4           0           1  10.66  12.880        56    11.0014     0   20
# ...       ...         ...    ...     ...       ...        ...   ...  ...
# 6488        0           1  10.66  12.880        60    11.0014     1   31
# 6489        0           1  10.66  12.880        60    11.0014     1   31
# 6490        0           1  10.66  12.880        60    11.0014     1   31
# 6491        0           1  10.66  13.635        56     8.9981     1   31
# 6492        0           1  10.66  13.635        65     8.9981     1   31
#
#       hour  season_1  ...  weather_2  weather_3  weather_4  dayofweek_0  \
# 0        0      True  ...      False      False      False        False
# 1        1      True  ...      False      False      False        False
# 2        2      True  ...      False      False      False        False
# 3        3      True  ...      False      False      False        False
# 4        4      True  ...      False      False      False        False
# ...    ...       ...  ...        ...        ...        ...          ...
# 6488    19      True  ...       True      False      False         True
# 6489    20      True  ...       True      False      False         True
# 6490    21      True  ...      False      False      False         True
# 6491    22      True  ...      False      False      False         True
# 6492    23      True  ...      False      False      False         True
#
#       dayofweek_1  dayofweek_2  dayofweek_3  dayofweek_4  dayofweek_5  \
# 0           False        False         True        False        False
# 1           False        False         True        False        False
# 2           False        False         True        False        False
# 3           False        False         True        False        False
# 4           False        False         True        False        False
# ...           ...          ...          ...          ...          ...
# 6488        False        False        False        False        False
# 6489        False        False        False        False        False
# 6490        False        False        False        False        False
# 6491        False        False        False        False        False
# 6492        False        False        False        False        False
#
#       dayofweek_6
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 6488        False
# 6489        False
# 6490        False
# 6491        False
# 6492        False
#
# [6493 rows x 24 columns]

# %% [markdown]
# # Training a random forest regression model

# %% [markdown]
# Creating a model and training it. We also used gridsearch for hyperparameter tuning (in kaggle_model.ipynb), but found best results by just using default parameters.

# %%
rfr = RandomForestRegressor(random_state=0, n_jobs=-1)
rfr.fit(X_train_rfr, y_train_rfr)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=0)

# %% [markdown]
# # Predicting the test results and writing them into a file

# %% [markdown]
# Predicting test data

# %%
y_test_rfr = rfr.predict(X_test_rfr)

# %% [markdown]
# Saving the results into a file

# %%
results_to_file(y_test_rfr, "submission_rfr_9")

# %% [markdown]
# Competition score (Root Mean Squared Logarithmic Error): 0.42960

# %% [markdown]
# # Preparing data for a Tensorflow model

# %% [markdown]
# We applied a cyclical transformation to the "hour" feature to capture its periodic nature. This is important because certain values, such as hours 23 and 0, are as close to each other as any other consecutive values. Without this transformation, their relationship would not be properly represented in the model.
#
# The transformation uses sine and cosine functions to map these cyclical values onto a continuous circle, ensuring the model can interpret their periodicity. The original month column was dropped after the transformation.

# %%
X_train_tf = X_train_rfr.copy()
y_train_tf = y_train_rfr.copy()

X_test_tf = X_test_rfr.copy()

X_train_tf["hour_sin"] = np.sin(2 * np.pi * X_train_tf["hour"] / 24)
X_train_tf["hour_cos"] = np.cos(2 * np.pi * X_train_tf["hour"] / 24)

X_test_tf["hour_sin"] = np.sin(2 * np.pi * X_test_tf["hour"] / 24)
X_test_tf["hour_cos"] = np.cos(2 * np.pi * X_test_tf["hour"] / 24)

X_train_tf.drop("hour", inplace=True, axis=1)
X_test_tf.drop("hour", inplace=True, axis=1)

# %% [markdown]
# We scaled the features to standardize them with a mean of 0 and a standard deviation of 1. This is essential for TensorFlow models, as neural networks are sensitive to the scale of input data. Without scaling, training can be slower, less stable, and biased toward features with larger magnitudes.

# %%
day_mean = 16
day_std = 8.8

X_train_tf["day"] = (X_train_tf["day"] - day_mean) / day_std
X_test_tf["day"] = (X_test_tf["day"] - day_mean) / day_std

scaler = StandardScaler()
X_train_tf = scaler.fit_transform(X_train_tf)
X_test_tf = scaler.transform(X_test_tf)

y_train_tf = np.array(y_train_tf).reshape(-1, 1)

# %% [markdown]
# # Training a Tensorflow model

# %% [markdown]
# Creating the model. To ensure predictions are always 0 or positive, we use an exponential activation function in the final layer. The model includes multiple dense layers with ReLU activation, batch normalization for stability, and dropout for regularization.

# %%
model = Sequential([
    Input(shape=(X_train_tf.shape[1],)),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(64, activation="relu"),
    BatchNormalization(),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(16, activation='relu'),
    Dense(1, activation='exponential')
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %% [markdown]
# Creating an early stopping function to prevent overfitting during training

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %% [markdown]
# Creating a function to reduce learning rate every 10 epochs.

# %%
def lr_scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch > 0:
        lr = lr * 0.9  # Reduce by 10% every 10 epochs
    return lr

lr_schedule = LearningRateScheduler(lr_scheduler)

# %% [markdown]
# Training the model

# %%
history = model.fit(
    X_train_tf, y_train_tf,
    epochs=200,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping, lr_schedule],
    verbose=1
)
# Out:
# Epoch 1/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 47869.5977 - mae: 156.3402 - val_loss: 77789.7969 - val_mae: 207.8105 - learning_rate: 0.0010
# Epoch 2/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27932.5195 - mae: 114.5333 - val_loss: 39570.9766 - val_mae: 133.5121 - learning_rate: 0.0010
# Epoch 3/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23840.6699 - mae: 103.0940 - val_loss: 34918.5352 - val_mae: 125.2165 - learning_rate: 0.0010
# Epoch 4/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31093.9512 - mae: 118.4119 - val_loss: 28570.6602 - val_mae: 113.2879 - learning_rate: 0.0010
# Epoch 5/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15088.7979 - mae: 82.4744 - val_loss: 19036.7168 - val_mae: 92.9247 - learning_rate: 0.0010
# Epoch 6/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13931.1943 - mae: 79.7091 - val_loss: 19501.2324 - val_mae: 94.5059 - learning_rate: 0.0010
# Epoch 7/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14684.4746 - mae: 81.7407 - val_loss: 22016.2246 - val_mae: 100.4125 - learning_rate: 0.0010
# Epoch 8/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16413.8164 - mae: 83.5650 - val_loss: 17019.4863 - val_mae: 88.1691 - learning_rate: 0.0010
# Epoch 9/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10084.9482 - mae: 68.0327 - val_loss: 22942.6328 - val_mae: 99.6591 - learning_rate: 0.0010
# Epoch 10/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37282.6328 - mae: 128.0523 - val_loss: 20949.1250 - val_mae: 97.5129 - learning_rate: 0.0010
# Epoch 11/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 12027.6699 - mae: 74.3470 - val_loss: 14114.6113 - val_mae: 78.3633 - learning_rate: 9.0000e-04
# Epoch 12/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9412.2549 - mae: 65.1497 - val_loss: 14057.7578 - val_mae: 79.8373 - learning_rate: 9.0000e-04
# Epoch 13/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10517.9756 - mae: 67.8942 - val_loss: 10934.8252 - val_mae: 70.2347 - learning_rate: 9.0000e-04
# Epoch 14/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7756.9937 - mae: 59.9241 - val_loss: 10710.2646 - val_mae: 70.5250 - learning_rate: 9.0000e-04
# Epoch 15/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8760.2129 - mae: 62.6732 - val_loss: 13458.7715 - val_mae: 78.7044 - learning_rate: 9.0000e-04
# Epoch 16/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7594.3428 - mae: 59.3686 - val_loss: 8957.9033 - val_mae: 65.3005 - learning_rate: 9.0000e-04
# Epoch 17/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6849.9521 - mae: 56.8635 - val_loss: 13157.1074 - val_mae: 77.6651 - learning_rate: 9.0000e-04
# Epoch 18/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8609.0068 - mae: 62.3722 - val_loss: 12595.4199 - val_mae: 76.1346 - learning_rate: 9.0000e-04
# Epoch 19/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9422.7158 - mae: 63.2552 - val_loss: 9984.7617 - val_mae: 67.8140 - learning_rate: 9.0000e-04
# Epoch 20/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6621.0718 - mae: 55.7802 - val_loss: 8010.4243 - val_mae: 62.0676 - learning_rate: 9.0000e-04
# Epoch 21/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6273.3379 - mae: 53.7283 - val_loss: 7442.2651 - val_mae: 59.2411 - learning_rate: 8.1000e-04
# Epoch 22/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5916.7485 - mae: 52.6267 - val_loss: 10115.9102 - val_mae: 68.1504 - learning_rate: 8.1000e-04
# Epoch 23/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5729.8491 - mae: 51.9289 - val_loss: 10937.3057 - val_mae: 71.6096 - learning_rate: 8.1000e-04
# Epoch 24/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5613.3208 - mae: 50.6965 - val_loss: 6870.2729 - val_mae: 56.8114 - learning_rate: 8.1000e-04
# Epoch 25/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5680.0791 - mae: 51.3017 - val_loss: 6599.2021 - val_mae: 55.0514 - learning_rate: 8.1000e-04
# Epoch 26/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5559.5972 - mae: 50.1519 - val_loss: 6151.6689 - val_mae: 54.0803 - learning_rate: 8.1000e-04
# Epoch 27/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5216.5635 - mae: 49.4407 - val_loss: 8093.2793 - val_mae: 59.5942 - learning_rate: 8.1000e-04
# Epoch 28/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4908.5635 - mae: 48.2431 - val_loss: 8348.5000 - val_mae: 61.2122 - learning_rate: 8.1000e-04
# Epoch 29/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 5034.0059 - mae: 48.2011 - val_loss: 8087.1045 - val_mae: 60.8260 - learning_rate: 8.1000e-04
# Epoch 30/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5052.5732 - mae: 49.0726 - val_loss: 7328.9795 - val_mae: 58.5396 - learning_rate: 8.1000e-04
# Epoch 31/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4574.5449 - mae: 46.3824 - val_loss: 5389.7358 - val_mae: 49.6013 - learning_rate: 7.2900e-04
# Epoch 32/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4996.7764 - mae: 48.1502 - val_loss: 8671.2773 - val_mae: 61.3479 - learning_rate: 7.2900e-04
# Epoch 33/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4900.5649 - mae: 46.9038 - val_loss: 8338.2119 - val_mae: 60.6361 - learning_rate: 7.2900e-04
# Epoch 34/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4675.4336 - mae: 46.7053 - val_loss: 6022.7935 - val_mae: 51.2568 - learning_rate: 7.2900e-04
# Epoch 35/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4407.4346 - mae: 45.5219 - val_loss: 6253.6040 - val_mae: 52.6931 - learning_rate: 7.2900e-04
# Epoch 36/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4061.0242 - mae: 44.3970 - val_loss: 6942.9805 - val_mae: 55.6707 - learning_rate: 7.2900e-04
# Epoch 37/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4292.6240 - mae: 44.8333 - val_loss: 4889.7959 - val_mae: 47.7141 - learning_rate: 7.2900e-04
# Epoch 38/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3832.9229 - mae: 42.2834 - val_loss: 7239.9185 - val_mae: 55.8412 - learning_rate: 7.2900e-04
# Epoch 39/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3755.2537 - mae: 42.3333 - val_loss: 8607.1553 - val_mae: 61.9331 - learning_rate: 7.2900e-04
# Epoch 40/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 4130.7744 - mae: 43.9902 - val_loss: 6195.3447 - val_mae: 53.6276 - learning_rate: 7.2900e-04
# Epoch 41/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3515.4827 - mae: 41.2920 - val_loss: 5084.6172 - val_mae: 49.3307 - learning_rate: 6.5610e-04
# Epoch 42/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4180.8823 - mae: 44.1733 - val_loss: 9937.3135 - val_mae: 66.5304 - learning_rate: 6.5610e-04
# Epoch 43/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4547.8398 - mae: 44.8372 - val_loss: 8875.8330 - val_mae: 63.8125 - learning_rate: 6.5610e-04
# Epoch 44/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4061.4343 - mae: 43.3610 - val_loss: 4842.6489 - val_mae: 47.2824 - learning_rate: 6.5610e-04
# Epoch 45/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3732.3762 - mae: 42.1850 - val_loss: 4772.4932 - val_mae: 46.6687 - learning_rate: 6.5610e-04
# Epoch 46/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3334.5786 - mae: 40.7410 - val_loss: 10343.1387 - val_mae: 67.7886 - learning_rate: 6.5610e-04
# Epoch 47/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8011.1006 - mae: 57.2581 - val_loss: 4974.7329 - val_mae: 48.1589 - learning_rate: 6.5610e-04
# Epoch 48/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3845.7249 - mae: 42.8957 - val_loss: 5448.3447 - val_mae: 49.7209 - learning_rate: 6.5610e-04
# Epoch 49/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3422.9268 - mae: 40.3560 - val_loss: 6091.8325 - val_mae: 52.0213 - learning_rate: 6.5610e-04
# Epoch 50/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3848.8406 - mae: 42.3615 - val_loss: 5902.0117 - val_mae: 50.9329 - learning_rate: 6.5610e-04
# Epoch 51/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3422.1206 - mae: 40.3415 - val_loss: 5222.9731 - val_mae: 48.5913 - learning_rate: 5.9049e-04
# Epoch 52/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3083.7356 - mae: 39.0158 - val_loss: 7682.5151 - val_mae: 58.1982 - learning_rate: 5.9049e-04
# Epoch 53/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4689.4033 - mae: 44.7773 - val_loss: 5882.8442 - val_mae: 52.2111 - learning_rate: 5.9049e-04
# Epoch 54/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3930.2388 - mae: 42.8211 - val_loss: 5613.1943 - val_mae: 50.8283 - learning_rate: 5.9049e-04
# Epoch 55/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3326.5879 - mae: 40.5122 - val_loss: 4679.6201 - val_mae: 46.1942 - learning_rate: 5.9049e-04
# Epoch 56/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3152.9390 - mae: 38.6522 - val_loss: 6003.1455 - val_mae: 52.6278 - learning_rate: 5.9049e-04
# Epoch 57/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3453.4766 - mae: 40.3507 - val_loss: 5415.2139 - val_mae: 50.3782 - learning_rate: 5.9049e-04
# Epoch 58/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2961.7854 - mae: 38.8033 - val_loss: 10397.3242 - val_mae: 69.9580 - learning_rate: 5.9049e-04
# Epoch 59/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6718.2969 - mae: 53.0357 - val_loss: 4249.5557 - val_mae: 44.6986 - learning_rate: 5.9049e-04
# Epoch 60/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3127.3579 - mae: 38.9573 - val_loss: 4518.5425 - val_mae: 45.4891 - learning_rate: 5.9049e-04
# Epoch 61/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2950.3704 - mae: 38.0276 - val_loss: 4361.1470 - val_mae: 44.7566 - learning_rate: 5.3144e-04
# Epoch 62/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2967.1919 - mae: 38.4318 - val_loss: 4900.1421 - val_mae: 47.4589 - learning_rate: 5.3144e-04
# Epoch 63/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2907.8391 - mae: 37.6605 - val_loss: 4224.8965 - val_mae: 43.1447 - learning_rate: 5.3144e-04
# Epoch 64/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3094.1587 - mae: 38.5663 - val_loss: 4197.8345 - val_mae: 43.2126 - learning_rate: 5.3144e-04
# Epoch 65/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2908.2258 - mae: 37.5724 - val_loss: 4840.7046 - val_mae: 47.6978 - learning_rate: 5.3144e-04
# Epoch 66/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3024.7617 - mae: 37.6182 - val_loss: 4722.0815 - val_mae: 46.1905 - learning_rate: 5.3144e-04
# Epoch 67/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3039.3589 - mae: 38.1858 - val_loss: 5334.2534 - val_mae: 49.8910 - learning_rate: 5.3144e-04
# Epoch 68/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3130.3923 - mae: 38.5670 - val_loss: 4302.7261 - val_mae: 44.2886 - learning_rate: 5.3144e-04
# Epoch 69/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3056.0669 - mae: 38.7400 - val_loss: 5149.0527 - val_mae: 48.1432 - learning_rate: 5.3144e-04
# Epoch 70/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2660.2576 - mae: 36.2167 - val_loss: 6245.3345 - val_mae: 53.9971 - learning_rate: 5.3144e-04
# Epoch 71/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3116.9556 - mae: 38.2523 - val_loss: 5888.2505 - val_mae: 52.3710 - learning_rate: 4.7830e-04
# Epoch 72/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3051.2246 - mae: 38.2541 - val_loss: 6037.0684 - val_mae: 52.3396 - learning_rate: 4.7830e-04
# Epoch 73/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2749.5789 - mae: 36.5272 - val_loss: 4779.2739 - val_mae: 46.6407 - learning_rate: 4.7830e-04
# Epoch 74/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2987.8123 - mae: 37.5846 - val_loss: 7053.8843 - val_mae: 56.4373 - learning_rate: 4.7830e-04
# Epoch 75/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3137.6519 - mae: 39.0060 - val_loss: 4867.9761 - val_mae: 46.7676 - learning_rate: 4.7830e-04
# Epoch 76/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2954.3916 - mae: 37.8407 - val_loss: 5205.0908 - val_mae: 48.3931 - learning_rate: 4.7830e-04
# Epoch 77/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3293.7251 - mae: 39.7717 - val_loss: 5980.0664 - val_mae: 52.0871 - learning_rate: 4.7830e-04
# Epoch 78/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3080.7556 - mae: 38.8881 - val_loss: 4420.0054 - val_mae: 44.2898 - learning_rate: 4.7830e-04
# Epoch 79/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2671.2461 - mae: 36.5805 - val_loss: 5002.9702 - val_mae: 47.2558 - learning_rate: 4.7830e-04
# Epoch 80/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3221.6765 - mae: 39.1160 - val_loss: 4138.8867 - val_mae: 42.9395 - learning_rate: 4.7830e-04
# Epoch 81/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2722.9634 - mae: 35.9154 - val_loss: 3822.0947 - val_mae: 40.6409 - learning_rate: 4.3047e-04
# Epoch 82/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2496.0645 - mae: 35.2170 - val_loss: 3673.6396 - val_mae: 40.0709 - learning_rate: 4.3047e-04
# Epoch 83/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2916.2341 - mae: 37.0761 - val_loss: 3725.6528 - val_mae: 40.2088 - learning_rate: 4.3047e-04
# Epoch 84/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2527.0984 - mae: 35.5528 - val_loss: 6393.3848 - val_mae: 53.2800 - learning_rate: 4.3047e-04
# Epoch 85/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2857.9053 - mae: 36.6930 - val_loss: 5347.1758 - val_mae: 49.1861 - learning_rate: 4.3047e-04
# Epoch 86/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2346.7556 - mae: 34.0949 - val_loss: 5234.1694 - val_mae: 48.4090 - learning_rate: 4.3047e-04
# Epoch 87/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2612.3857 - mae: 35.3929 - val_loss: 4302.6196 - val_mae: 43.2645 - learning_rate: 4.3047e-04
# Epoch 88/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2377.0684 - mae: 34.2608 - val_loss: 3633.4617 - val_mae: 39.5205 - learning_rate: 4.3047e-04
# Epoch 89/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2713.3318 - mae: 36.3002 - val_loss: 5545.8379 - val_mae: 50.0529 - learning_rate: 4.3047e-04
# Epoch 90/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2394.8245 - mae: 34.2021 - val_loss: 4524.4888 - val_mae: 44.7752 - learning_rate: 4.3047e-04
# Epoch 91/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2248.2754 - mae: 33.2920 - val_loss: 3948.1841 - val_mae: 41.0219 - learning_rate: 3.8742e-04
# Epoch 92/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2527.2612 - mae: 34.8743 - val_loss: 4218.2764 - val_mae: 43.0043 - learning_rate: 3.8742e-04
# Epoch 93/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 2460.1038 - mae: 34.8506 - val_loss: 4373.0991 - val_mae: 43.7327 - learning_rate: 3.8742e-04
# Epoch 94/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2446.1782 - mae: 34.9279 - val_loss: 3811.9141 - val_mae: 40.9472 - learning_rate: 3.8742e-04
# Epoch 95/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2490.0239 - mae: 35.0260 - val_loss: 4213.0596 - val_mae: 43.2497 - learning_rate: 3.8742e-04
# Epoch 96/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2292.4800 - mae: 33.3514 - val_loss: 3975.2498 - val_mae: 41.5183 - learning_rate: 3.8742e-04
# Epoch 97/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2377.8176 - mae: 33.6951 - val_loss: 6217.3721 - val_mae: 52.4218 - learning_rate: 3.8742e-04
# Epoch 98/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3580.4729 - mae: 38.9282 - val_loss: 4944.7275 - val_mae: 47.5660 - learning_rate: 3.8742e-04
# Epoch 99/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2302.5188 - mae: 33.5071 - val_loss: 5117.5332 - val_mae: 47.3315 - learning_rate: 3.8742e-04
# Epoch 100/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2484.6560 - mae: 34.3316 - val_loss: 3993.0635 - val_mae: 41.7605 - learning_rate: 3.8742e-04
# Epoch 101/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2399.3716 - mae: 34.3497 - val_loss: 4196.3164 - val_mae: 43.0506 - learning_rate: 3.4868e-04
# Epoch 102/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2369.5479 - mae: 33.8254 - val_loss: 6144.2612 - val_mae: 52.9777 - learning_rate: 3.4868e-04
# Epoch 103/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2423.4727 - mae: 34.5994 - val_loss: 4049.9900 - val_mae: 42.4197 - learning_rate: 3.4868e-04
# Epoch 104/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2426.6873 - mae: 34.3681 - val_loss: 4452.0752 - val_mae: 44.5468 - learning_rate: 3.4868e-04
# Epoch 105/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2156.7712 - mae: 32.5889 - val_loss: 4105.0894 - val_mae: 42.5567 - learning_rate: 3.4868e-04
# Epoch 106/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2194.6060 - mae: 33.4457 - val_loss: 5101.3350 - val_mae: 47.1261 - learning_rate: 3.4868e-04
# Epoch 107/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2301.3940 - mae: 33.6858 - val_loss: 4284.1079 - val_mae: 43.7334 - learning_rate: 3.4868e-04
# Epoch 108/200
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2172.2654 - mae: 33.0698 - val_loss: 5678.9116 - val_mae: 50.5494 - learning_rate: 3.4868e-04

# %% [markdown]
# # Predicting the test results and writing them into a file

# %% [markdown]
# Predicting test data

# %%
y_test_tf = model.predict(X_test_tf)
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# Saving the results into a file

# %%
y_test_tf = [element[0] for element in y_test_tf] 
results_to_file(y_test_tf, "submission_tf_6")

# %% [markdown]
# Competition score (Root Mean Squared Logarithmic Error): 0.50451
